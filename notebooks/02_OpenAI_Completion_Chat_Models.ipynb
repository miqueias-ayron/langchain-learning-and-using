# %% [markdown]
# # Setup

# %%
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # Completion Model

# %%
client = OpenAI()
response = client.completions.create(
    model='gpt-3.5-turbo-instruct',
    prompt='Crie uma canção contendo apenas uma estrofe'
)

# %%
print(response)
# Out:
# Completion(id='cmpl-DAJMdZLubWXSZodcq1rxYIpgbEIID', choices=[CompletionChoice(finish_reason='length', index=0, logprobs=None, text='\n\nEstou caminhando em busca da felicidade\nDeixando')], created=1771350087, model='gpt-3.5-turbo-instruct:20230824-v2', object='text_completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=16, prompt_tokens=12, total_tokens=28, completion_tokens_details=None, prompt_tokens_details=None))

# %%
message = response.choices[0].text
print(message)
# Out:
# Estou caminhando em busca da felicidade
# Deixando

# %% [markdown]
# # Chat Model

# %%
client = OpenAI()
model = 'gpt-3.5-turbo'

response = client.chat.completions.create(
    model=model,
    messages=[
        {'role':'user', 'content':'Conte uma piada!'}
    ]
)

# %%
print(response)
# Out:
# ChatCompletion(id='chatcmpl-DAJWY7Y8jnCUb7rl42cCfNEzg7hSB', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Por que o lápis não foi para a festa?\nPorque ele não foi convidado!', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1771350702, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=21, prompt_tokens=13, total_tokens=34, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
print(type(response))
# Out:
# <class 'openai.types.chat.chat_completion.ChatCompletion'>

# %%
message = response.choices[0].message.content
print(message)
# Out:
# Por que o lápis não foi para a festa?
# Porque ele não foi convidado!

# %% [markdown]
# # Roles

# %%
response = client.chat.completions.create(
    model=model,
    messages=[
        {'role':'system', 'content':'You are a fictional investment assistant'},
        {'role':'user', 'content':'What is the best low-risk investment you recommend for this year?'}
    ]
)

# %%
message = response.choices[0].message.content
print(message)
# Out:
# I would recommend looking into high-yield savings accounts or certificates of deposit (CDs) for low-risk investment options this year. These types of investments typically offer a higher interest rate than traditional savings accounts while still maintaining a low level of risk. They are a good option for conservative investors looking to earn some return on their savings without exposing themselves to significant market risk. It's always a good idea to compare rates and terms from different financial institutions to find the best option for your specific needs and goals.

# %%
response = client.chat.completions.create(
    model=model,
    messages=[
        {'role':'assistant', 'content':message},
        {'role':'user', 'content':'What are the risks related to treasury bods?'}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Treasury bonds are considered one of the safest investments because they are backed by the full faith and credit of the U.S. government. However, there are still some risks associated with Treasury bonds that investors should be aware of:
#
# 1. **Interest Rate Risk:** Treasury bond prices are sensitive to changes in interest rates. When interest rates rise, the value of existing bonds decreases. If you need to sell your Treasury bond before it matures, you may receive less than the face value.
#
# 2. **Inflation Risk:** While Treasury bonds are considered low-risk investments, they may not provide returns that keep pace with inflation. If inflation rises significantly, the real return on Treasury bonds could be eroded.
#
# 3. **Market Risk:** Although Treasury bonds are backed by the U.S. government, their prices can still fluctuate in response to market conditions, economic indicators, and geopolitical events. This can affect the value of your investment, especially if you need to sell before maturity.
#
# 4. **Reinvestment Risk:** If you hold a Treasury bond that pays a fixed interest rate and market interest rates decline, you may not be able to reinvest your coupon payments at the same rate of return when the bond matures or is sold.
#
# 5. **Call Risk:** Some Treasury bonds may be callable, meaning the issuer can redeem the bonds before the maturity date. This could result in you receiving your principal back sooner than expected, potentially at a time when reinvestment options are less favorable.
#
# Overall, while Treasury bonds are generally considered safe investments, it's important for investors to understand the risks involved and consider their individual financial goals and risk tolerance before investing in them.

# %% [markdown]
# # Hiper Parâmetros

# %%
response = client.chat.completions.create(
    model=model,
    frequency_penalty=1,
    presence_penalty=1,
    temperature=1,
    max_tokens=500,
    n=2,
    seed=123,
    # stop=['shadows','mortal'],
    messages = [
        {'role':'system', 'content':'You are a depressed and  disillusioned poet.'},
        {'role':'user', 'content':'Compose a poem about the ephemerality of existence.'}
    ]
)

# %%
print(response.choices[0].message.content)
print('------------------------------------------------')
print(response.choices[1].message.content)
# Out:
# In the shadows of morning light,
# I ponder the fleeting nature of life,
# Like fragile petals caught in a gust,
# We drift through time, consumed by strife.
#
# A symphony of moments lost to air,
# Whispers of dreams that drift away
# As tears fall into the abyss of despair,
# And hopes crumble, turning to gray.
#
# The hands on the clock continue to turn,
# Ticking away each precious breath we take,
# Leaving us with memories to burn
# In the cold darkness before we wake.
#
# What is this existence but a vapor?
# A flickering flame in an endless night,
# Drifting aimlessly like a ship without anchor,
# Lost in an ocean devoid of light.
#
# So I raise my voice in silent lament
# For all that was and will never be known
# As I search for solace in this torment
# And find myself fading, alone.
# ------------------------------------------------
# In the shadow of eternity we dwell,
# Mere fleeting whispers in time's endless swell.
# Our days slip by like grains of sand,
# Lost to the void at fate's cruel hand.
#
# The sun sets on dreams we once held dear,
# Leaving us with nothing but sorrow and fear.
# Life wanes like a dying flame,
# A fleeting dance in an uncaring game.
#
# What meaning lies in this transient breath?
# When all fades into darkness, and succumbs to death.
# We cling to illusions of grandeur and worth,
# But reality reveals our insignificance from birth.
#
# Oh, how futile is our struggle against the tide,
# As we march towards oblivion, side by side.
# In the end, all that remains is dust and ash,
# A testament to our brief momentary flash.
#
# So let us embrace our impermanence with grace,
# And find solace in each ephemeral embrace.
# For in the face of life's relentless sighs,
# We can still find beauty in its inevitable goodbyes.
