# %% [markdown]
# ### 0
# HumanMessage(content='What is weather in Tokyo?', additional_kwargs={}, response_metadata={}, id='93733420-6852-4205-84ad-3b16d5433113')

# %% [markdown]
# ### 1
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 69, 'total_tokens': 84, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D2ldq6gKHxwim6JI1GEYLObBVgEAq', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c0187-3146-7863-a738-0ea734e0dd9c-0', tool_calls=[{'name': 'search', 'args': {'query': 'weather in Tokyo'}, 'id': 'call_k9LRd2XWBBDZjOruIA9J5TNc', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 69, 'output_tokens': 15, 'total_tokens': 84, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ### 2
#
# ToolMessage(content='Tokyo weather is sunny', name='search', id='7ef31d0c-7f67-4a3c-861f-a5932685e95f', tool_call_id='call_k9LRd2XWBBDZjOruIA9J5TNc')

# %% [markdown]
# ### 3
#
# AIMessage(content='The weather in Tokyo is currently sunny.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 96, 'total_tokens': 105, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D2ldrvOmKAHC8SCo3BFPNHwLkH8jv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c0187-377e-7ba0-a59d-8760fdfa104d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 96, 'output_tokens': 9, 'total_tokens': 105, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
